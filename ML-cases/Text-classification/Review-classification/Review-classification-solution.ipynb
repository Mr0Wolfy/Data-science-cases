# %%
# Импорт необходимх библиотек
import numpy as np
import pandas as pd

import nltk
from nltk.corpus import stopwords


from string import punctuation
from collections import Counter

import pymorphy3

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, accuracy_score
from sklearn.model_selection import train_test_split

from catboost import CatBoostClassifier

# %%
# Загружаем данные
df_banks = pd.read_csv("C:\\Users\\Mr0Wo\\OneDrive\\Рабочий стол\\Git_repositories\\Data-science-cases\\ML-cases\\Text-classification\\Review-classification\\banks.csv", sep='\t', index_col='idx')

# %%
df_banks.head()
# Out:
#         Score                                               Text
# idx
# 0    Positive  В Альфа-Банке работает замечательная девушка -...
# 1    Negative  Оформляя рассрочку в м. Видео в меге тёплый ст...
# 2    Positive  Очень порадовала оперативность работы в банке....
# 3    Negative  Имела неосторожность оформить потреб. кредит в...
# 4    Negative  Небольшая предыстория: Нашел на сайте MDM банк...

# %%
# Проверяем баланс классов
df_banks['Score'].value_counts(normalize=True)
# Out:
# Positive    0.500036
# Negative    0.499964
# Name: Score, dtype: float64

# %%
# Делаем маппинг, меняя Positive на 1, а Negative на 0
df_banks['Score'] = df_banks['Score'].map({'Positive':1, 'Negative':0})

# %%
# Создаем токенайзен
morph = pymorphy3.MorphAnalyzer()
ru_stopwords = stopwords.words("russian")
def tokenizer(text):
    lemma_tokens = []  # Массив для обработанных токенов
    tokens = nltk.word_tokenize(text.lower())  # Текст превращаем в токены, заодно переводя в нижний регистра
    tokens = [token for token in tokens if token not in punctuation]  # Убираем все знаки пунктуации
    tokens = [token for token in tokens if token not in ru_stopwords]  # Убираем стоп-слова
    tokens = [token for token in tokens if token not in ['.', '..', '...', '....']]  # Убираем многоточия
    for token in tokens:  # Цикл, в котором мы проходимся по всем токенам в предложении
        token = morph.parse(token)[0].normal_form  # Лематизируем (приводим к начальной форме) токены
        lemma_tokens.append(token)  # Добавляем подготовленные токены в массив
    return lemma_tokens

# %%
# Проверка работы функции
tokenizer(df_banks.iloc[0]['Text'])
# Out:
# ['альфа-банк',
#  'работать',
#  'замечательный',
#  'девушка',
#  'ильясова',
#  'орный',
#  'вежливый',
#  'отзывчивый',
#  'действительно',
#  'участвовать',
#  'запрос',
#  'клиент',
#  'приходить',
#  'подряд',
#  'ровно',
#  'день',
#  'каждый',
#  'день',
#  'помнить',
#  'время',
#  'мой',
#  'приход',
#  'помочь',
#  'оформить',
#  'кредит',
#  'размер',
#  '1млн',
#  'рубль',
#  'прийти',
#  'партнёр',
#  'передавать',
#  'получить',
#  'кредит',
#  'покупать',
#  'я',
#  'авто',
#  'специалист',
#  'ильясова',
#  'орный',
#  'помочь',
#  'мы',
#  'вывести',
#  'сумма',
#  'день',
#  'это',
#  'непросто',
#  'сделка',
#  'состояться',
#  'остаться',
#  'довольный',
#  'знакомый',
#  'конец',
#  'добавить',
#  'понять',
#  'почему',
#  'прислать',
#  'это',
#  'отделение',
#  'девушка',
#  'большой',
#  'такой',
#  'замечательный',
#  'специалист',
#  'приобретать',
#  'программа',
#  'здоровье',
#  'вообще',
#  'связать',
#  'альфа-банк',
#  'быть']

# %%
# Применяем токенайзер к нашим данным, а результат сохраняем в отдельный столбец
df_banks['Tokens'] = df_banks['Text'].apply(lambda row: tokenizer(row))

# %%
df_banks.head(10)
# Out:
#      Score                                               Text  \
# idx
# 0        1  В Альфа-Банке работает замечательная девушка -...
# 1        0  Оформляя рассрочку в м. Видео в меге тёплый ст...
# 2        1  Очень порадовала оперативность работы в банке....
# 3        0  Имела неосторожность оформить потреб. кредит в...
# 4        0  Небольшая предыстория: Нашел на сайте MDM банк...
# 5        1  В конце февраля оформила кредитную карту банка...
# 6        0  Месяц назад взял автокредит. До этого ходили п...
# 7        0  Не говоря про махинации с бонусами, остановлюс...
# 8        0  День добрый, моя мама С-на В.А.,1932г рождения...
# 9        0  Всех приветствую.Я являюсь клиентом этого чудо...
#
#                                                 Tokens
# idx
# 0    [альфа-банк, работать, замечательный, девушка,...
# 1    [оформлять, рассрочка, м., видео, мег, тёплый,...
# 2    [очень, порадовать, оперативность, работа, бан...
# 3    [иметь, неосторожность, оформить, потреба, кре...
# 4    [небольшой, предыстория, найти, сайт, mdm, бан...
# 5    [конец, февраль, оформить, кредитный, карта, б...
# 6    [месяц, назад, взять, автокредит, ходить, разн...
# 7    [говорить, махинация, бонус, остановиться, про...
# 8    [день, добрый, мама, с-на, в.а.,1932г, рождени...
# 9    [приветствую.ть, являться, клиент, чудо-банка,...

# %%
# Создаем словарь, в котором подсчитывем кол-во появлений каждого слова
words = Counter()
for txt in df_banks['Tokens']: 
    words.update(txt)
len(words)
# Out:
# 90824

# %%
words
# Out:
# Counter({'альфа-банк': 4359,
#          'работать': 5517,
#          'замечательный': 418,
#          'девушка': 3742,
#          'ильясова': 2,
#          'орный': 2,
#          'вежливый': 1815,
#          'отзывчивый': 160,
#          'действительно': 1149,
#          'участвовать': 86,
#          'запрос': 983,
#          'клиент': 12681,
#          'приходить': 2359,
#          'подряд': 107,
#          'ровно': 288,
#          'день': 15729,
#          'каждый': 2420,
#          'помнить': 718,
#          'время': 8957,
#          'мой': 15645,
#          'приход': 149,
#          'помочь': 2302,
#          'оформить': 3888,
#          'кредит': 14490,
#          'размер': 1319,
#          '1млн': 1,
#          'рубль': 4661,
#          'прийти': 5239,
#          'партнёр': 305,
#          'передавать': 163,
#          'получить': 7620,
#          'покупать': 400,
#          'я': 3455,
#          'авто': 233,
#          'специалист': 3228,
#          'мы': 2020,
#          'вывести': 119,
#          'сумма': 8931,
#          'это': 18561,
#          'непросто': 16,
#          'сделка': 1436,
#          'состояться': 172,
#          'остаться': 1721,
#          'довольный': 1319,
#          'знакомый': 818,
#          'конец': 1770,
#          'добавить': 357,
#          'понять': 1490,
#          'почему': 3102,
#          'прислать': 1140,
#          'отделение': 13414,
#          'большой': 1593,
#          'такой': 7452,
#          'приобретать': 63,
#          'программа': 1351,
#          'здоровье': 221,
#          'вообще': 2547,
#          'связать': 237,
#          'быть': 4404,
#          'оформлять': 1444,
#          'рассрочка': 456,
#          'м.': 306,
#          'видео': 65,
#          'мег': 46,
#          'тёплый': 74,
#          'стан': 14,
#          'попросить': 2136,
#          'менеджер': 3625,
#          'заявка': 4351,
#          'страховка': 2354,
#          'итог': 2606,
#          'подписывать': 507,
#          'договор': 6277,
#          'оказаться': 2435,
#          'лишний': 603,
#          '6': 867,
#          'тысяча': 991,
#          'стать': 3407,
#          'спрашивать': 933,
#          'нервничать': 88,
#          'говорить': 4427,
#          'какой-то': 2332,
#          'чушь': 28,
#          'скидка': 230,
#          'течение': 3032,
#          'три': 497,
#          'месяц': 5947,
#          'полностью': 942,
#          'закрой': 138,
#          'действовать': 605,
#          'пытаться': 1389,
#          'найти': 1403,
#          'что-то': 1601,
#          'начало': 1374,
#          'посчитать': 283,
#          'правда': 1068,
#          'нету': 97,
#          'пара': 1395,
#          'тщательно': 55,
#          'спокойный': 206,
#          'обстановка': 121,
#          'полистать': 4,
#          'кредитный': 8834,
#          'который': 14519,
#          'просить': 2844,
#          'вопрос': 9638,
#          'заговаривать': 3,
#          'зуб': 35,
#          'рассказывать': 364,
#          'зачем-то': 38,
#          'свой': 9610,
#          'якобы': 525,
#          'банк': 58189,
#          'отстоять': 155,
#          'очередь': 4091,
#          'час': 3016,
#          'сказать': 9990,
#          'мочь': 7660,
#          'отказаться': 1410,
#          'деньга': 13701,
#          'вернуть': 2201,
#          'пройти': 2368,
#          '5': 2848,
#          'оформление': 2223,
#          'также': 3149,
#          'условие': 3446,
#          'участие': 271,
#          'страхование': 1580,
#          'рука': 1194,
#          'выдать': 2589,
#          'лишь': 758,
#          'пункт': 680,
#          '14': 491,
#          'стоить': 1206,
#          'ознакомлена.замечательный': 1,
#          'работа': 6252,
#          'спихнуть': 3,
#          'процент': 3595,
#          'человек': 4634,
#          'потерять': 680,
#          'бдительность': 17,
#          'делать': 2540,
#          'нужно': 3371,
#          'подписание': 450,
#          'документ': 5890,
#          'читать': 758,
#          'запятая': 19,
#          'должный': 3888,
#          'адекватный': 245,
#          'этот': 2419,
#          'отвечать': 1703,
#          'внятно': 101,
#          'психовать': 8,
#          'объяснить': 2350,
#          'очень': 9226,
#          'порадовать': 353,
#          'оперативность': 420,
#          'заказать': 845,
#          'интернет': 2036,
#          'карта': 30560,
#          'visa': 656,
#          'classic': 173,
#          'потребоваться': 294,
#          'подойти': 960,
#          'заявление': 6466,
#          'открыть': 2847,
#          'текущий': 961,
#          'счёт': 13681,
#          'доступ': 504,
#          'услуга': 5456,
#          'альфа-клик': 435,
#          'неделя': 3074,
#          'научить': 103,
#          'сбербанк': 2499,
#          'ожидать': 750,
#          'обещать': 1364,
#          'удивиться': 263,
#          'вовремя': 582,
#          'минута': 4624,
#          'оператор': 3430,
#          'воронежский': 18,
#          'пр-тот': 34,
#          'революция': 17,
#          'добродушный': 18,
#          'проконсультировать': 225,
#          'весь': 4232,
#          'ситуация': 4676,
#          'уточнял.после': 1,
#          'захотеть': 244,
#          'подключить': 1128,
#          'альфа-мобайл': 60,
#          'управление': 180,
#          'телефон': 6084,
#          'забыть': 813,
#          'логин': 217,
#          'позвонить': 5951,
#          'горячий': 2260,
#          'линия': 2630,
#          'подсказать': 361,
#          'обращение': 2874,
#          'выслать': 290,
#          'sms': 313,
#          'ссылка': 245,
#          'приложение': 521,
#          'сервис': 1303,
#          'уровень': 870,
#          'настоящий': 506,
#          'момент': 2956,
#          'являться': 3536,
#          'московский': 653,
#          'индустриальный': 14,
#          'втб': 189,
#          '24': 422,
#          'сотрудничество': 704,
#          'последний': 2118,
#          '2мя': 1,
#          'разочаровать': 123,
#          'другой': 5084,
#          'история': 2167,
#          'единственный': 903,
#          'хотеться': 1927,
#          'посоветовать': 663,
#          'расширить': 58,
#          'клиентский': 389,
#          'зона': 76,
#          'г.': 2761,
#          'воронеж': 79,
#          'тесновато': 8,
#          'иметь': 2854,
#          'неосторожность': 31,
#          'потреба': 108,
#          'жалеть': 88,
#          'во-первых': 273,
#          'наличие': 629,
#          'во-вторых': 193,
#          'никакой': 3687,
#          'информация': 3929,
#          'предоставлять': 489,
#          'бред': 154,
#          'отправлять': 475,
#          'отд': 49,
#          'тот': 3044,
#          'кто': 906,
#          'поблизости': 19,
#          'необходимо': 1042,
#          'проконсультироваться': 95,
#          'общий': 2527,
#          'огромный': 1263,
#          'минус': 936,
#          'обслуживание': 5615,
#          'отношение': 2762,
#          'надеяться': 1389,
#          'расплатиться': 153,
#          'точно': 924,
#          'администратор': 1123,
#          'какой': 3461,
#          'хотеть': 5629,
#          'консультация': 643,
#          'k': 9,
#          'tuwk': 1,
#          'оформляться': 161,
#          'связный': 102,
#          '16': 390,
#          'июнь': 822,
#          'повод': 1064,
#          'нужный': 2383,
#          'интересовать': 403,
#          'воспользоваться': 913,
#          'кто-то': 707,
#          'собственно': 435,
#          'оплачивать': 947,
#          'график': 528,
#          'платёж': 6144,
#          'разобраться': 1390,
#          'графика': 162,
#          'указать': 1927,
#          'дата': 1589,
#          'списание': 1265,
#          'рекомендовать': 841,
#          'оплата': 2385,
#          'небольшой': 954,
#          'предыстория': 47,
#          'сайт': 3535,
#          'mdm': 6,
#          'интересный': 630,
#          'ко-бренд': 7,
#          '«': 5144,
#          'техносить': 30,
#          '–': 2802,
#          '»': 5103,
#          'подать': 1329,
#          'скоро': 259,
#          'предложить': 2682,
#          'принцип': 514,
#          'ответить': 2991,
#          'дебетовый': 1767,
#          'справка': 1713,
#          'всякий': 882,
#          'случай': 2725,
#          'одобрить': 1387,
#          'обратиться': 3820,
#          'моментальный': 132,
#          'выдача': 1051,
#          'специально': 355,
#          'уточнить': 1522,
#          'далеко': 290,
#          'ехать': 729,
#          'раз': 2026,
#          'туда': 840,
#          'выбрать': 1071,
#          'оо': 49,
#          'самарский': 30,
#          'слово': 2344,
#          'город': 1359,
#          'поездка': 372,
#          'режим': 246,
#          'позволять': 350,
#          'приехать': 1600,
#          '1.5': 98,
#          'закрытие': 1623,
#          'решить': 5780,
#          'подстраховаться': 19,
#          'моментально': 182,
#          'усилие': 136,
#          'тщетный': 12,
#          'попадать': 252,
#          'отсылать': 59,
#          'отдел': 1463,
#          'продажа': 341,
#          'переключение': 46,
#          'трубка': 726,
#          'никто': 2289,
#          'брать': 2148,
#          '29': 250,
#          'апрель': 977,
#          '2016': 733,
#          'год': 10378,
#          'поехать': 680,
#          'прибыть': 65,
#          '1': 2107,
#          '20': 1251,
#          'перед': 189,
#          '2': 4076,
#          'сотрудник': 14527,
#          'рабочий': 1866,
#          'один': 4853,
#          'сотрудница': 2101,
#          'спросить': 1397,
#          'рассказать': 1501,
#          'закончиться': 671,
#          'уйти': 1132,
#          'к': 802,
#          'второй': 1700,
#          'подождать': 793,
#          'т.к': 2964,
#          'выяснить': 731,
#          'друг': 1990,
#          'передать': 728,
#          'ответ': 5845,
#          'скорый': 220,
#          'домой': 551,
#          'разбираться': 559,
#          'получение': 2324,
#          'проверка': 533,
#          '10': 2771,
#          'разрез': 5,
#          'отксерить': 13,
#          'паспорт': 1505,
#          'выпуск': 681,
#          'т.п': 304,
#          'писать': 2915,
#          'взять': 2756,
#          'разрешение': 228,
#          'использование': 556,
#          'персональный': 650,
#          'данные': 1372,
#          'простой': 842,
#          'сделать': 4601,
#          'ранний': 1017,
#          'номер': 5037,
#          'дать': 5873,
#          'визитка': 67,
#          'имя': 1278,
#          'б': 117,
#          'рёв': 2,
#          'альбина': 22,
#          'с-на': 12,
#          'дозвониться': 787,
#          'трубки.ть': 1,
#          'многий': 496,
#          'госучреждение': 7,
#          'видеть': 1790,
#          'разный': 1205,
#          'отвратительный': 218,
#          'встречать': 391,
#          'май': 915,
#          '2016год': 1,
#          'путаться': 39,
#          'несколько': 3673,
#          'название': 241,
#          'вариант': 837,
#          'её': 1208,
#          'жизнь': 948,
#          'честно': 741,
#          'первый': 3948,
#          'слышать': 486,
#          'прийтись': 2288,
#          'отказаться.p.s': 1,
#          'контактный': 487,
#          'центр': 1087,
#          'мдм': 466,
#          'подтвердить': 737,
#          'бесплатно': 633,
#          'какой-либо': 548,
#          'неимёный': 1,
#          'считать': 1490,
#          'просто-напросто': 9,
#          'обманывает.p.s': 1,
#          'соотноситься': 4,
#          'возможность': 2106,
#          'немногословный': 2,
#          'обращать': 196,
#          'ваш': 5558,
#          'внимание': 1310,
#          'вправе': 85,
#          'отказать': 910,
#          'карты.': 6,
#          'вообщий-то': 4,
#          'сомневаться': 149,
#          '.в': 218,
#          'потратить': 882,
#          'куча': 460,
#          'мнение': 542,
#          'испортить': 282,
#          'февраль': 855,
#          'авангард': 1474,
#          'качество': 1199,
#          'непредвиденный': 24,
#          'удивить': 592,
#          'скоростной': 4,
#          'профессиональный': 447,
#          'мини-офис': 48,
#          'санкт-петербург': 394,
#          'пражский': 7,
#          'ул.': 21,
#          '48/50': 2,
#          'трк': 22,
#          'южный': 40,
#          'полюс': 10,
#          'процедура': 695,
#          'занять': 814,
#          '10-15': 105,
#          'мин.по': 1,
#          'прошествие': 117,
#          'обнаружить': 675,
#          'нехватка': 29,
#          'депозитный': 149,
#          'ощущение': 361,
#          'полнота': 13,
#          'свобода': 28,
#          'колебание': 14,
#          'сей': 1134,
#          'просто': 4494,
#          'потрясти': 12,
#          'шесть': 90,
#          'депозит': 1153,
#          'валюта': 795,
#          'уверить': 356,
#          'вскоре': 81,
#          'оценить': 200,
#          'несомненный': 20,
#          'преимущества.фантастика': 1,
#          'заключаться': 161,
#          'выйти': 726,
#          'офис': 7472,
#          'счастливый': 180,
#          'обладательница': 19,
#          'заветный': 72,
#          'буквально': 493,
#          'благодаря': 540,
#          'оперативный': 419,
#          'локтионов': 1,
#          'анне': 94,
#          'иванович': 55,
#          'кстати': 924,
#          'удача': 210,
#          'настроиться': 19,
#          '2-3': 277,
#          'viva': 2,
#          'назад': 1781,
#          'автокредит': 545,
#          'ходить': 505,
#          'салон': 267,
#          'форд': 26,
#          'присматривать': 7,
#          'машина': 693,
#          'исходить': 135,
#          'конкретный': 475,
#          'автомобиль': 396,
#          'первоначальный': 281,
#          'взнос': 500,
#          'автосалон': 292,
#          'навязывать': 200,
#          'именно': 2120,
#          'париб': 46,
#          'восток': 49,
#          'мол': 553,
#          'выгодный': 570,
#          'самый': 2562,
#          'льготный': 604,
#          'сильно': 443,
#          'отличаться': 167,
#          'убеждать': 73,
#          'консультант': 695,
#          'кредитование': 688,
#          'одинаковый': 93,
#          'исходный': 28,
#          'сидеть': 742,
#          'рассчитывать': 252,
#          'совершенно': 564,
#          '3': 2835,
#          'насчитать': 56,
#          '60': 332,
#          'тыс.руб': 53,
#          '90': 140,
#          'тыс.': 47,
#          '180': 66,
#          'консультант-продавец': 1,
#          'возмущение': 131,
#          'девочка': 410,
#          'неграмотный': 22,
#          'постоянно': 795,
#          'меняться': 238,
#          'результат': 1516,
#          'купить': 631,
#          'включить': 274,
#          'упомянуть': 104,
#          'наш': 2618,
#          'вино': 156,
#          'провести': 1170,
#          'долго': 1211,
#          'всё': 2782,
#          'слабо': 22,
#          'соображать': 20,
#          'корка': 11,
#          'мало': 728,
#          'предупредить': 513,
#          'т.е': 1123,
#          'поздний': 790,
#          'узнать': 2080,
#          'всё-таки': 863,
#          'застраховать': 165,
#          'оплатить': 1888,
#          'наличные': 520,
#          'полный': 1672,
#          'приходиться': 840,
#          'заниматься': 709,
#          'расторжение': 351,
#          'страховой': 1048,
#          'компания': 1179,
#          'тратить': 538,
#          'главное': 723,
#          'покупка': 1853,
#          'ради': 220,
#          'интерес': 227,
#          'рассчитать': 215,
#          'выплата': 576,
#          'абсолют': 414,
#          'параметр': 82,
#          '500-600': 2,
#          'ниже': 302,
#          'официальный': 441,
#          'хороший': 2675,
#          'услышать': 521,
#          'любой': 1882,
#          'проблема': 6765,
#          'завести': 279,
#          'он-лайна': 159,
#          'перечисление': 255,
#          'проверить': 976,
#          'обслуживаться': 1139,
#          'перевод': 3055,
#          'допустить': 217,
#          'платить': 1825,
#          'терминал': 995,
#          'сколько': 1175,
#          '100': 803,
#          'пожалеть': 142,
#          'связаться': 1144,
#          'непонятно': 321,
#          'поверить': 234,
#          'убеждение': 16,
#          'сам': 3391,
#          'проверять': 444,
#          'взвешивать': 5,
#          'давний': 88,
#          'махинация': 17,
#          'бонус': 688,
#          'остановиться': 123,
#          'среднемесячный': 20,
#          'остаток': 1179,
#          'средство': 4412,
#          'усыплять': 1,
#          'начислять': 231,
#          'правильно': 462,
#          'согласно': 528,
#          'третий': 788,
#          'вместо': 706,
#          'начислить': 781,
#          'потеря': 339,
#          'около': 1828,
#          '2-й': 405,
#          'соответственно': 574,
#          'порядок': 1110,
#          '25': 507,
#          '000': 1740,
#          'больший': 1170,
#          'неприятно': 190,
#          'подобный': 819,
#          'крысятничество': 1,
#          'позиционировать': 24,
#          'крупный': 675,
#          'россия': 723,
#          'высокий': 1014,
#          'отдача': 5,
#          'ответственность': 264,
#          'естественно': 745,
#          'решиться': 278,
#          'убить': 59,
#          'хождение': 31,
#          'написание': 341,
#          'претензия': 5396,
#          'учитывать': 348,
#          'эмоция': 338,
#          'снять': 1794,
#          'иметься': 644,
#          'увы': 174,
#          'банкомат': 6110,
#          'опустошить': 2,
#          'добрый': 2053,
#          'мама': 471,
#          'в.а.,1932г': 1,
#          'рождение': 217,
#          'пенсионерка': 34,
#          'бинбанка': 1584,
#          'октябрь': 794,
#          '2015': 554,
#          'пенсия': 182,
#          'срок': 4111,
#          'перевыпустить': 534,
#          'с-ин': 1,
#          'геннадий': 14,
#          'алексеевич': 48,
#          'сын': 145,
#          'неоднократно': 400,
#          'она': 355,
#          'обращаться': 1678,
#          'ул': 1170,
#          'никитинский': 2,
#          '2015г': 54,
#          'перевести': 1290,
#          'место': 1684,
#          'г.воронеж': 15,
#          'ул.куцыгин': 1,
#          '32': 65,
#          'помещение': 259,
#          '№4': 11,
#          'предлог': 46,
#          'перевыпускать': 97,
#          '…': 80,
#          'система': 1933,
#          'ещё': 1665,
#          'причину.ь': 1,
#          '84': 23,
#          'приезжать': 446,
#          'безрезультатно': 62,
#          'март': 1218,
#          '2016г': 86,
#          'филиал': 1176,
#          'адрес': 2099,
#          'ул.генерал': 2,
#          'лизюков': 7,
#          'д.23': 4,
#          'отфутболить': 18,
#          'сослаться': 134,
#          'явиться': 135,
#          'старший': 299,
#          'начать': 1390,
#          'предпринимать': 36,
#          'фото': 103,
#          'пообещать': 368,
#          'следующий': 2907,
#          'звонок': 5062,
#          'поступать': 739,
#          'подумать': 721,
#          'сегодня': 2996,
#          '22': 310,
#          '03': 34,
#          'ошибка': 2001,
#          'программный': 108,
#          'обеспечение': 124,
#          'удивительно': 94,
#          'звонить': 5567,
#          'руководство': 888,
#          'давать': 1529,
#          'бардак': 143,
#          'понятно': 848,
#          'уважение': 785,
#          'с-кина': 1,
#          'г.а': 3,
#          '8950': 1,
#          '0237': 1,
#          'приветствую.ть': 1,
#          'чудо-банка': 5,
#          '04101473481': 1,
#          'сентябрь': 742,
#          'года.переть': 2,
#          'заключение': 349,
#          'эксперт': 134,
#          'заказывать': 391,
#          'досрочный': 1147,
#          'погашение': 2252,
#          'внести': 2009,
#          'заранее': 611,
#          'ёж': 7,
#          'месячный': 90,
#          'списать': 1431,
#          'ноябрь': 870,
#          'озвучить': 349,
#          '23': 278,
#          'декабрь': 1219,
#          'далее': 1421,
#          'вновь': 440,
#          'разговор': 1162,
#          'увидеть': 1126,
#          'заказ': 351,
#          'оказываться': 796,
#          'стрясти': 3,
#          'немедленно': 124,
#          'расчёт': 488,
#          'произвести': 496,
#          'разговоре.жда': 1,
#          'кредитка': 1118,
#          'из-за': 1481,
#          'стоимость': 550,
#          'удобство': 263,
#          'маленький': 1197,
#          'дважды': 313,
#          'увеличивать': 88,
#          'отказ': 1551,
#          'удобный': 1367,
#          'инет-банкинг': 4,
#          'практически': 644,
#          'коммуналка': 77,
#          'родственник': 312,
#          'поскольку': 731,
#          'коммунальный': 169,
#          'контора': 142,
#          'сбер': 858,
#          'собрать': 227,
#          'р.': 602,
#          'толкаться': 4,
#          'прошлый': 538,
#          'инфолайна': 1,
#          'использовать': 625,
#          'карточка': 1682,
#          'весьма': 335,
#          'активно': 295,
#          'бесплатный.посоветовать': 1,
#          'двоюродный': 3,
#          'брат': 112,
#          'прописка': 151,
#          'регистрация': 495,
#          'пользоваться': 3757,
#          'метро.ну': 1,
#          'пожелание': 267,
#          'кобрендинг': 3,
#          'желательно': 47,
#          'аэрофлот': 220,
#          'люберцы': 29,
#          'заезжать': 42,
#          'городок': 25,
#          'удобно': 1153,
#          'близкий': 1144,
#          'дом': 1099,
#          'северный': 84,
#          'часть': 874,
#          'ops': 72,
#          'пока': 2361,
#          'получать': 2082,
#          'подача': 490,
#          'pingva': 1,
#          'полянка': 58,
#          'дней.обслуживаться': 1,
#          'частый': 211,
#          'автозаводский': 28,
#          '01.07.2015': 8,
#          'пополнять': 372,
#          'зачислить': 742,
#          'зачисление': 549,
#          'отмениться': 5,
#          'отразить': 63,
#          'смс-сообщение': 142,
#          'сразу': 3313,
#          'поступили.спасибо': 1,
#          'искренний': 178,
#          'признательность': 94,
#          'работник': 1048,
#          'мособлбанк': 147,
#          'человечность': 27,
#          'понимание': 425,
#          'впервые': 341,
#          'финансовый': 613,
#          'организация': 1032,
#          'настолько': 238,
#          'входить': 239,
#          'клиентов.этый': 2,
#          'ведение': 135,
#          'иной': 417,
#          'учреждение': 134,
#          'упоминать': 45,
#          'наименование': 66,
#          'причина': 1623,
#          'смена': 417,
#          'приятно': 1548,
#          'поразить': 201,
#          'расторопность': 5,
#          'курьёзный': 4,
#          'своевременно': 183,
#          'известить': 71,
#          'дорога': 311,
#          'попасть': 785,
#          'авария': 7,
#          'казаться': 602,
#          'перезвонить': 1366,
#          'дождаться': 376,
#          'хотя': 2965,
#          'опоздать': 56,
#          '40': 516,
#          'минут.спасибо': 2,
#          'админ': 534,
#          'произойти': 1282,
#          'описывать': 149,
#          'отзыв': 3426,
#          'uliss_1': 1,
#          'переведеновский': 1,
#          'переулок': 62,
#          'модератор': 43,
#          'удалять': 25,
#          'оставить': 1794,
#          'изменение': 610,
#          'адресат': 26,
#          'дойдет.прочитать': 1,
#          'немало': 67,
#          '500': 469,
#          'шт.': 2,
#          'вывод': 457,
#          'минимум': 455,
#          'десять': 168,
#          'устать': 136,
#          'измучиться': 3,
#          'разозлить': 14,
#          'довести': 108,
#          'белый': 151,
#          'колено': 9,
#          'бесконечный': 80,
#          'неправомерный': 81,
#          'оскорблять': 28,
#          'запугивать': 20,
#          'тупой': 49,
#          'чудо': 350,
#          'заколлекторско-заколебать': 1,
#          'агентство': 206,
#          'дойти': 353,
#          'знать': 3944,
#          'должник': 332,
#          'назойливость': 9,
#          'мягко': 133,
#          'неграмотность': 16,
#          'собраться': 138,
#          'вместе': 499,
#          'урок': 26,
#          'конкретно': 221,
#          'протяжение': 342,
#          'ежедневно': 107,
#          'круглосуточно': 69,
#          'искать': 612,
#          'неведомый': 23,
#          'б-кина': 2,
#          'а.в': 26,
#          'полгода': 507,
#          'особый': 319,
#          'подробно': 602,
#          'объяснять': 872,
#          'гражданин': 221,
#          'ноль': 131,
#          'игнорить': 3,
#          'ставить': 694,
#          'чёрный': 222,
#          'список': 483,
#          'бесполезно': 87,
#          'идти': 1992,
#          'плюс': 1185,
#          'прибавиться': 12,
#          'угроза': 330,
#          'арестовать': 34,
#          'имущество': 142,
#          'описать': 489,
#          'посадить': 43,
#          'снабдить': 5,
#          'полномочие': 51,
#          'юрист': 242,
#          'долгосрочный': 54,
#          'отпуск': 419,
#          'закон': 617,
#          'пахнуть': 12,
#          'капля': 73,
#          'ночью': 144,
#          '2.30.': 1,
#          'очередной': 1194,
#          'сообщить': 3363,
#          'выезжать': 67,
#          'наряд': 16,
#          'полиция': 246,
#          'пристав': 155,
#          'глянуть': 9,
#          'регион': 176,
#          'россия-матушка': 1,
#          'вы': 537,
#          'часовой': 34,
#          'пояс': 9,
#          'разница': 280,
#          'аж': 212,
#          '7': 966,
#          'учесть': 138,
#          'отец': 127,
#          'трое': 42,
#          'ребёнок': 521,
#          'младший': 10,
#          'доставать': 103,
#          'настоятельно': 73,
#          'прекратить': 272,
#          'искомый': 10,
#          'принадлежать': 109,
#          'образ': 923,
#          'база': 630,
#          'контакт': 283,
#          'записать': 333,
#          'предъявлены.заявление': 1,
#          'жалоба': 1072,
#          'прокуратура': 261,
#          'цб': 376,
#          'написать': 4909,
#          'продолжаться': 330,
#          'чт': 2,
#          'поданы.просить': 1,
#          'тон': 208,
#          'прощение': 52,
#          'проникнуться': 19,
#          'просьба': 1644,
#          'спасибо': 3799,
#          'действие': 1512,
#          'происходить': 858,
#          'площадь': 118,
#          'островский': 13,
#          '2009': 249,
#          'пятница': 435,
#          '17-00.': 8,
#          'операционист': 1204,
#          'занятый': 278,
#          'дело': 2514,
#          'современный': 129,
#          'информационный': 181,
#          'заставить': 196,
#          'уважать': 77,
#          'предъявить': 109,
#          'талончик': 120,
#          'ожидание': 1055,
#          '0': 249,
#          'непродолжительный': 18,
#          'безобразие': 86,
#          'производительность': 4,
#          'труд': 200,
#          'банковский': 1701,
#          'сфера': 166,
#          'мировой': 39,
#          'уровня.ссылка': 1,
#          'http': 339,
#          '//xandublin.livejournal.com/17914.html': 1,
#          '//www.youtube.com/watch': 2,
#          'v=hisfobwrguy': 1,
#          'feature=player_embedded': 1,
#          '8604/115': 1,
#          'светлана': 257,
#          'анатолий': 16,
#          'помощь': 1263,
#          'тула': 36,
#          'заключить': 368,
#          'инкассация': 215,
#          '31': 204,
#          ...})

# %%
# Словарь, отображающий слова в коды
word_to_index = dict()
# Словарь, отображающий коды в слова
index_to_word = dict()
# В цикле проходимся по отсортированному словарю, индексируем слова и наоборот
for i, word in enumerate(words.most_common(10000 - 2)):
    word_to_index[word[0]] = i + 2
    index_to_word[i + 2] = word[0]

# %%
word_to_index
# Out:
# {'банк': 2,
#  'карта': 3,
#  'это': 4,
#  'день': 5,
#  'мой': 6,
#  'сотрудник': 7,
#  'который': 8,
#  'кредит': 9,
#  'деньга': 10,
#  'счёт': 11,
#  'отделение': 12,
#  'клиент': 13,
#  'год': 14,
#  'сказать': 15,
#  'вопрос': 16,
#  'свой': 17,
#  'очень': 18,
#  'время': 19,
#  'сумма': 20,
#  'кредитный': 21,
#  'мочь': 22,
#  'получить': 23,
#  'офис': 24,
#  'такой': 25,
#  'проблема': 26,
#  'заявление': 27,
#  'договор': 28,
#  'работа': 29,
#  'платёж': 30,
#  'банкомат': 31,
#  'телефон': 32,
#  'позвонить': 33,
#  'месяц': 34,
#  'документ': 35,
#  'дать': 36,
#  'ответ': 37,
#  'решить': 38,
#  'хотеть': 39,
#  'обслуживание': 40,
#  'звонить': 41,
#  'ваш': 42,
#  'работать': 43,
#  'услуга': 44,
#  'претензия': 45,
#  'прийти': 46,
#  'вклад': 47,
#  '«': 48,
#  '»': 49,
#  'другой': 50,
#  'звонок': 51,
#  'номер': 52,
#  'написать': 53,
#  'один': 54,
#  'ситуация': 55,
#  'рубль': 56,
#  'человек': 57,
#  'минута': 58,
#  'сделать': 59,
#  'просто': 60,
#  'говорить': 61,
#  'средство': 62,
#  'быть': 63,
#  'альфа-банк': 64,
#  'заявка': 65,
#  'весь': 66,
#  'срок': 67,
#  'очередь': 68,
#  '2': 69,
#  'первый': 70,
#  'знать': 71,
#  'информация': 72,
#  'новый': 73,
#  'оформить': 74,
#  'должный': 75,
#  'обратиться': 76,
#  'спасибо': 77,
#  'смс': 78,
#  'пользоваться': 79,
#  'девушка': 80,
#  'данный': 81,
#  'комиссия': 82,
#  'никакой': 83,
#  'несколько': 84,
#  'менеджер': 85,
#  'процент': 86,
#  'являться': 87,
#  'сайт': 88,
#  'операция': 89,
#  'какой': 90,
#  'я': 91,
#  'условие': 92,
#  'оператор': 93,
#  'отзыв': 94,
#  'стать': 95,
#  'сам': 96,
#  'решение': 97,
#  'нужно': 98,
#  'сообщить': 99,
#  'ждать': 100,
#  'сразу': 101,
#  'специалист': 102,
#  'также': 103,
#  'почему': 104,
#  'неделя': 105,
#  'перевод': 106,
#  'тот': 107,
#  'течение': 108,
#  'час': 109,
#  'сегодня': 110,
#  'ответить': 111,
#  'хотя': 112,
#  'т.к': 113,
#  'момент': 114,
#  'писать': 115,
#  'следующий': 116,
#  'обращение': 117,
#  'иметь': 118,
#  '5': 119,
#  'открыть': 120,
#  'просить': 121,
#  '3': 122,
#  '–': 123,
#  'всё': 124,
#  '10': 125,
#  'отношение': 126,
#  'г.': 127,
#  'взять': 128,
#  'быстро': 129,
#  'случай': 130,
#  'предложить': 131,
#  'хороший': 132,
#  'линия': 133,
#  'наш': 134,
#  'задолженность': 135,
#  'итог': 136,
#  'выдать': 137,
#  'самый': 138,
#  'вообще': 139,
#  'делать': 140,
#  'общий': 141,
#  'дело': 142,
#  'принять': 143,
#  'сбербанк': 144,
#  'лимит': 145,
#  'оказаться': 146,
#  'каждый': 147,
#  'этот': 148,
#  'смочь': 149,
#  'руб': 150,
#  'оплата': 151,
#  'нужный': 152,
#  'пройти': 153,
#  'пока': 154,
#  'приходить': 155,
#  'страховка': 156,
#  'объяснить': 157,
#  'думать': 158,
#  'слово': 159,
#  'какой-то': 160,
#  'получение': 161,
#  'помочь': 162,
#  'никто': 163,
#  'прийтись': 164,
#  'горячий': 165,
#  'погашение': 166,
#  'альфа': 167,
#  'оформление': 168,
#  'вернуть': 169,
#  'история': 170,
#  'брать': 171,
#  'попросить': 172,
#  'именно': 173,
#  'последний': 174,
#  '1': 175,
#  'возможность': 176,
#  'сотрудница': 177,
#  'адрес': 178,
#  'закрыть': 179,
#  'получать': 180,
#  'узнать': 181,
#  'добрый': 182,
#  'служба': 183,
#  'интернет': 184,
#  'раз': 185,
#  'мы': 186,
#  'внести': 187,
#  'ошибка': 188,
#  'идти': 189,
#  'друг': 190,
#  'система': 191,
#  'хотеться': 192,
#  'указать': 193,
#  'оплатить': 194,
#  'снова': 195,
#  'любой': 196,
#  'рабочий': 197,
#  'москва': 198,
#  'денежный': 199,
#  'покупка': 200,
#  'около': 201,
#  'лицо': 202,
#  'платить': 203,
#  'положительный': 204,
#  'вежливый': 205,
#  'отправить': 206,
#  'снять': 207,
#  'оставить': 208,
#  'поэтому': 209,
#  'видеть': 210,
#  'назад': 211,
#  'касса': 212,
#  'связь': 213,
#  'конец': 214,
#  'поддержка': 215,
#  'дебетовый': 216,
#  'два': 217,
#  '000': 218,
#  'остаться': 219,
#  'справка': 220,
#  'предоставить': 221,
#  'отвечать': 222,
#  'банковский': 223,
#  'второй': 224,
#  'погасить': 225,
#  'место': 226,
#  'карточка': 227,
#  'письмо': 228,
#  'обращаться': 229,
#  'полный': 230,
#  'ещё': 231,
#  'понимать': 232,
#  'просьба': 233,
#  'долг': 234,
#  'рассмотрение': 235,
#  'закрытие': 236,
#  'причина': 237,
#  'ставка': 238,
#  'открытие': 239,
#  'что-то': 240,
#  'приехать': 241,
#  'большой': 242,
#  'продукт': 243,
#  'дата': 244,
#  'находиться': 245,
#  'бинбанка': 246,
#  'страхование': 247,
#  'отказ': 248,
#  'приятно': 249,
#  'сторона': 250,
#  'давать': 251,
#  'личный': 252,
#  'уточнить': 253,
#  'результат': 254,
#  'действие': 255,
#  'выписка': 256,
#  'паспорт': 257,
#  'рассказать': 258,
#  'понять': 259,
#  'считать': 260,
#  '4': 261,
#  'из-за': 262,
#  'авангард': 263,
#  '30': 264,
#  'магазин': 265,
#  'отдел': 266,
#  'тариф': 267,
#  'оформлять': 268,
#  'кол-центр': 269,
#  'число': 270,
#  'сделка': 271,
#  'списать': 272,
#  'далее': 273,
#  'дополнительный': 274,
#  'отказаться': 275,
#  'найти': 276,
#  'спросить': 277,
#  'пара': 278,
#  'разобраться': 279,
#  'начать': 280,
#  'пытаться': 281,
#  'надеяться': 282,
#  'одобрить': 283,
#  'благодарность': 284,
#  'начало': 285,
#  'данные': 286,
#  'бинбанк': 287,
#  'удобный': 288,
#  'перезвонить': 289,
#  'обещать': 290,
#  'готовый': 291,
#  'город': 292,
#  'программа': 293,
#  'предложение': 294,
#  'пойти': 295,
#  'почта': 296,
#  'подать': 297,
#  'составить': 298,
#  'размер': 299,
#  'довольный': 300,
#  'внимание': 301,
#  'анкета': 302,
#  'сервис': 303,
#  'пора': 304,
#  '15': 305,
#  'мобильный': 306,
#  'перевести': 307,
#  'произойти': 308,
#  'имя': 309,
#  'общение': 310,
#  'необходимый': 311,
#  'списание': 312,
#  'огромный': 313,
#  'помощь': 314,
#  'причём': 315,
#  '20': 316,
#  'поступить': 317,
#  'возврат': 318,
#  'декабрь': 319,
#  'бесплатный': 320,
#  'отметить': 321,
#  'март': 322,
#  'снятие': 323,
#  'квартира': 324,
#  'долго': 325,
#  'её': 326,
#  'наличный': 327,
#  'стоить': 328,
#  'разный': 329,
#  'операционист': 330,
#  'заполнить': 331,
#  'интернет-банк': 332,
#  'некоторый': 333,
#  'качество': 334,
#  'маленький': 335,
#  'штраф': 336,
#  'рука': 337,
#  'очередной': 338,
#  'подписать': 339,
#  'период': 340,
#  'плюс': 341,
#  'компания': 342,
#  'остаток': 343,
#  'зарплатный': 344,
#  'филиал': 345,
#  'сколько': 346,
#  'провести': 347,
#  'больший': 348,
#  'ул': 349,
#  'забрать': 350,
#  'представитель': 351,
#  'зайти': 352,
#  'разговор': 353,
#  'просрочка': 354,
#  'сообщение': 355,
#  'депозит': 356,
#  'удобно': 357,
#  'действительно': 358,
#  'досрочный': 359,
#  'связаться': 360,
#  'близкий': 361,
#  'прислать': 362,
#  'обслуживаться': 363,
#  'сей': 364,
#  'уйти': 365,
#  'возникнуть': 366,
#  'подключить': 367,
#  'увидеть': 368,
#  'однако': 369,
#  'администратор': 370,
#  'т.е': 371,
#  'впечатление': 372,
#  'приятный': 373,
#  'кредитка': 374,
#  'порядок': 375,
#  'видимо': 376,
#  'пакет': 377,
#  'дом': 378,
#  'заблокировать': 379,
#  'право': 380,
#  'центр': 381,
#  'достаточно': 382,
#  'жалоба': 383,
#  'выбрать': 384,
#  'копия': 385,
#  'правда': 386,
#  'повод': 387,
#  'либо': 388,
#  'ожидание': 389,
#  'выдача': 390,
#  'страховой': 391,
#  'работник': 392,
#  'электронный': 393,
#  'сожаление': 394,
#  'необходимо': 395,
#  'положить': 396,
#  'организация': 397,
#  'давно': 398,
#  'предлагать': 399,
#  'оценка': 400,
#  'ранний': 401,
#  'высокий': 402,
#  'требовать': 403,
#  'факт': 404,
#  'терминал': 405,
#  'тысяча': 406,
#  'далёкий': 407,
#  'принимать': 408,
#  'лично': 409,
#  'запрос': 410,
#  'апрель': 411,
#  'проверить': 412,
#  'возможно': 413,
#  '7': 414,
#  'начаться': 415,
#  'текущий': 416,
#  'подойти': 417,
#  'альф': 418,
#  'небольшой': 419,
#  'закрытый': 420,
#  'жизнь': 421,
#  'оплачивать': 422,
#  'вид': 423,
#  'полностью': 424,
#  'минус': 425,
#  'суд': 426,
#  'спрашивать': 427,
#  'точно': 428,
#  'кстати': 429,
#  'образ': 430,
#  'руководитель': 431,
#  'кроме': 432,
#  'курс': 433,
#  'май': 434,
#  'январь': 435,
#  'общаться': 436,
#  'посмотреть': 437,
#  'воспользоваться': 438,
#  'сначала': 439,
#  'отказать': 440,
#  'кто': 441,
#  'открывать': 442,
#  'быстрый': 443,
#  'единственный': 444,
#  'оперативно': 445,
#  'рассмотреть': 446,
#  'потребительский': 447,
#  'поставить': 448,
#  'руководство': 449,
#  'опыт': 450,
#  'всякий': 451,
#  'потратить': 452,
#  'требование': 453,
#  'ипотека': 454,
#  'часть': 455,
#  'объяснять': 456,
#  'снимать': 457,
#  'чек': 458,
#  'уровень': 459,
#  'ноябрь': 460,
#  '6': 461,
#  'август': 462,
#  'годовой': 463,
#  'всё-таки': 464,
#  '№': 465,
#  'сбер': 466,
#  'происходить': 467,
#  'сообщать': 468,
#  'февраль': 469,
#  'купюра': 470,
#  'технический': 471,
#  'процесс': 472,
#  'выразить': 473,
#  'понятно': 474,
#  'понравиться': 475,
#  'заказать': 476,
#  'заплатить': 477,
#  'отсутствие': 478,
#  'ранее': 479,
#  'простой': 480,
#  'рекомендовать': 481,
#  'туда': 482,
#  'приходиться': 483,
#  'вариант': 484,
#  '8': 485,
#  'июль': 486,
#  'июнь': 487,
#  'фамилия': 488,
#  'подобный': 489,
#  'ежемесячный': 490,
#  'знакомый': 491,
#  'указанный': 492,
#  'занять': 493,
#  'забыть': 494,
#  'чётко': 495,
#  'бывать': 496,
#  'форма': 497,
#  'появиться': 498,
#  'возникать': 499,
#  '100': 500,
#  'к': 501,
#  'уважаемый': 502,
#  'оказываться': 503,
#  'попытка': 504,
#  'валюта': 505,
#  'постоянно': 506,
#  'октябрь': 507,
#  'подождать': 508,
#  'решать': 509,
#  'примерно': 510,
#  'поздний': 511,
#  'вернуться': 512,
#  'акция': 513,
#  'третий': 514,
#  'дозвониться': 515,
#  'уважение': 516,
#  'попасть': 517,
#  'телефонный': 518,
#  'дальнейший': 519,
#  'начислить': 520,
#  'желание': 521,
#  'назвать': 522,
#  'вчера': 523,
#  'персонал': 524,
#  'здравствуйте': 525,
#  'утро': 526,
#  'например': 527,
#  'вносить': 528,
#  'лишь': 529,
#  'читать': 530,
#  'кабинет': 531,
#  'управлять': 532,
#  'вроде': 533,
#  'получиться': 534,
#  'спустя': 535,
#  'ожидать': 536,
#  'старый': 537,
#  'несмотря': 538,
#  'жена': 539,
#  'цель': 540,
#  'как-то': 541,
#  'смотреть': 542,
#  'рф': 543,
#  'естественно': 544,
#  'выясниться': 545,
#  'выдавать': 546,
#  'ипотечный': 547,
#  'сидеть': 548,
#  'сентябрь': 549,
#  'зачислить': 550,
#  'честно': 551,
#  'интернет-банка': 552,
#  'сетель': 553,
#  'поступать': 554,
#  'расчётный': 555,
#  'получаться': 556,
#  'подтвердить': 557,
#  '2016': 558,
#  'выяснить': 559,
#  'поскольку': 560,
#  'ехать': 561,
#  'передать': 562,
#  'мало': 563,
#  'молодой': 564,
#  'трубка': 565,
#  'выйти': 566,
#  'перевыпуск': 567,
#  'главное': 568,
#  'россия': 569,
#  'выпустить': 570,
#  'плохой': 571,
#  'немного': 572,
#  'подумать': 573,
#  'менее': 574,
#  'помнить': 575,
#  'оставаться': 576,
#  'наверное': 577,
#  'проходить': 578,
#  'кассир': 579,
#  'ладный': 580,
#  'начинать': 581,
#  'заниматься': 582,
#  'отдельный': 583,
#  'кто-то': 584,
#  'равно': 585,
#  'вместо': 586,
#  'сотрудничество': 587,
#  'пожалуйста': 588,
#  'активировать': 589,
#  'нравиться': 590,
#  'процедура': 591,
#  'консультант': 592,
#  'ставить': 593,
#  'машина': 594,
#  'основание': 595,
#  'вечером': 596,
#  'кредитование': 597,
#  'бонус': 598,
#  'согласиться': 599,
#  'онлайн': 600,
#  'евро': 601,
#  'зарплата': 602,
#  'выбор': 603,
#  'отличный': 604,
#  'выпуск': 605,
#  'внесение': 606,
#  'сутки': 607,
#  'досрочно': 608,
#  'пункт': 609,
#  'потерять': 610,
#  'поехать': 611,
#  'необходимость': 612,
#  'обнаружить': 613,
#  'крупный': 614,
#  'реквизит': 615,
#  'закончиться': 616,
#  'доллар': 617,
#  'бумага': 618,
#  'целое': 619,
#  'посоветовать': 620,
#  'составлять': 621,
#  'особенно': 622,
#  'сбой': 623,
#  'обслуживать': 624,
#  'стоять': 625,
#  'собираться': 626,
#  'обычно': 627,
#  'visa': 628,
#  'подпись': 629,
#  'недавно': 630,
#  'московский': 631,
#  'персональный': 632,
#  'тыс': 633,
#  'уведомление': 634,
#  '2014': 635,
#  'иметься': 636,
#  'практически': 637,
#  'консультация': 638,
#  'остальной': 639,
#  'пополнение': 640,
#  'минимальный': 641,
#  'завтра': 642,
#  'затем': 643,
#  'собственный': 644,
#  'количество': 645,
#  'бесплатно': 646,
#  'купить': 647,
#  'интересный': 648,
#  'база': 649,
#  'муж': 650,
#  'наличие': 651,
#  'ткс': 652,
#  'срочно': 653,
#  'правило': 654,
#  'использовать': 655,
#  'безопасность': 656,
#  'закон': 657,
#  'финансовый': 658,
#  'искать': 659,
#  'заранее': 660,
#  'изменение': 661,
#  'успеть': 662,
#  'отрицательный': 663,
#  'действовать': 664,
#  'часто': 665,
#  'льготный': 666,
#  'лишний': 667,
#  'процентный': 668,
#  'р.': 669,
#  'казаться': 670,
#  'подробно': 671,
#  'мера': 672,
#  'жить': 673,
#  'русский': 674,
#  'выходной': 675,
#  'заметить': 676,
#  'товар': 677,
#  'одобрение': 678,
#  'довольно': 679,
#  'пять': 680,
#  'невозможно': 681,
#  'удивить': 682,
#  'предыдущий': 683,
#  'т.д': 684,
#  'сложиться': 685,
#  'вечер': 686,
#  'подавать': 687,
#  'удаться': 688,
#  'профессионализм': 689,
#  'возможный': 690,
#  'стандарт': 691,
#  '9': 692,
#  'вовремя': 693,
#  'отключить': 694,
#  'оставлять': 695,
#  'пример': 696,
#  'отдать': 697,
#  'предоставление': 698,
#  'пользование': 699,
#  'код': 700,
#  'нормальный': 701,
#  'выплата': 702,
#  'транзакция': 703,
#  'соответственно': 704,
#  'совершить': 705,
#  'выгодный': 706,
#  'подтверждение': 707,
#  'письменный': 708,
#  '12': 709,
#  'совершенно': 710,
#  'план': 711,
#  'устраивать': 712,
#  'разбираться': 713,
#  'руб.': 714,
#  'проспект': 715,
#  'использование': 716,
#  '2015': 717,
#  'мол': 718,
#  'крайне': 719,
#  'домой': 720,
#  'ввести': 721,
#  'стоимость': 722,
#  'доход': 723,
#  'зачисление': 724,
#  'подходить': 725,
#  'посещение': 726,
#  'закрывать': 727,
#  'какой-либо': 728,
#  'автокредит': 729,
#  '50': 730,
#  'мнение': 731,
#  'удивление': 732,
#  'встреча': 733,
#  'благодаря': 734,
#  'желать': 735,
#  'продолжать': 736,
#  'выше': 737,
#  'тратить': 738,
#  'прошлый': 739,
#  'вы': 740,
#  'понедельник': 741,
#  'визит': 742,
#  'долгий': 743,
#  'перевыпустить': 744,
#  'админ': 745,
#  'проводить': 746,
#  'проверка': 747,
#  'заверить': 748,
#  'просрочить': 749,
#  'рядом': 750,
#  'платёжный': 751,
#  'график': 752,
#  'согласно': 753,
#  'тип': 754,
#  'пароль': 755,
#  'якобы': 756,
#  'никак': 757,
#  'случиться': 758,
#  'заявить': 759,
#  '21': 760,
#  'операционистка': 761,
#  'согласие': 762,
#  'приложение': 763,
#  'услышать': 764,
#  'ребёнок': 765,
#  'наличные': 766,
#  'абсолютно': 767,
#  'зарегистрировать': 768,
#  '40': 769,
#  'принцип': 770,
#  'задать': 771,
#  'предупредить': 772,
#  'направить': 773,
#  'начисление': 774,
#  'переводить': 775,
#  'обычный': 776,
#  'поблагодарить': 777,
#  'привести': 778,
#  'нормально': 779,
#  'попробовать': 780,
#  'вполне': 781,
#  'выполнить': 782,
#  'баланс': 783,
#  'подписывать': 784,
#  '25': 785,
#  'полгода': 786,
#  'валютный': 787,
#  'держать': 788,
#  'настоящий': 789,
#  'ходить': 790,
#  'обязательно': 791,
#  'доступ': 792,
#  '2013': 793,
#  '11': 794,
#  'где-то': 795,
#  'состояние': 796,
#  'взнос': 797,
#  'внимательный': 798,
#  'вместе': 799,
#  'спокойно': 800,
#  'три': 801,
#  'коллега': 802,
#  'многий': 803,
#  'произвести': 804,
#  'вынудить': 805,
#  'регистрация': 806,
#  'буквально': 807,
#  '14': 808,
#  'мкб': 809,
#  'подача': 810,
#  'предоставлять': 811,
#  'описать': 812,
#  'расчёт': 813,
#  'пояснить': 814,
#  'контактный': 815,
#  'слышать': 816,
#  'пополнить': 817,
#  'доп': 818,
#  'список': 819,
#  'точка': 820,
#  'себя': 821,
#  'исправить': 822,
#  'ооо': 823,
#  'понадобиться': 824,
#  'отказываться': 825,
#  'негативный': 826,
#  'прочитать': 827,
#  'обратно': 828,
#  'заходить': 829,
#  'отправлять': 830,
#  'конкретный': 831,
#  'решаться': 832,
#  'извинение': 833,
#  'обязательство': 834,
#  'мама': 835,
#  'они': 836,
#  'суббота': 837,
#  '500': 838,
#  'елена': 839,
#  'постоянный': 840,
#  'мдм': 841,
#  'значит': 842,
#  'полис': 843,
#  'плата': 844,
#  'кодовый': 845,
#  'правильно': 846,
#  'иб': 847,
#  '18': 848,
#  'куча': 849,
#  'помогать': 850,
#  'принести': 851,
#  'вход': 852,
#  'способ': 853,
#  'вывод': 854,
#  'рассрочка': 855,
#  'распечатать': 856,
#  'минимум': 857,
#  'оба': 858,
#  'нерв': 859,
#  'что': 860,
#  'подписание': 861,
#  'утром': 862,
#  'платный': 863,
#  'почему-то': 864,
#  'компьютер': 865,
#  'профессиональный': 866,
#  'мелочь': 867,
#  'ольга': 868,
#  'попытаться': 869,
#  'рассматривать': 870,
#  'приезжать': 871,
#  'разговаривать': 872,
#  'граница': 873,
#  'столкнуться': 874,
#  'прямо': 875,
#  'показать': 876,
#  'проверять': 877,
#  'мина': 878,
#  'окончание': 879,
#  'сильно': 880,
#  'узнавать': 881,
#  'уточнять': 882,
#  'официальный': 883,
#  'центральный': 884,
#  'оно': 885,
#  'относиться': 886,
#  'реклама': 887,
#  'вновь': 888,
#  'супруг': 889,
#  'грамотный': 890,
#  'послать': 891,
#  'компетентный': 892,
#  'обратить': 893,
#  'альфа-клик': 894,
#  'собственно': 895,
#  'пятница': 896,
#  'вина': 897,
#  'заполнять': 898,
#  'называть': 899,
#  'объяснение': 900,
#  'планировать': 901,
#  'удивлённый': 902,
#  'успешно': 903,
#  'александр': 904,
#  'понимание': 905,
#  'учёт': 906,
#  'страна': 907,
#  'пусть': 908,
#  '24': 909,
#  'оперативность': 910,
#  'соответствовать': 911,
#  'екатерина': 912,
#  'оперативный': 913,
#  'отпуск': 914,
#  'поменять': 915,
#  'замечательный': 916,
#  '—': 917,
#  'иной': 918,
#  'смена': 919,
#  '3-й': 920,
#  'заёмщик': 921,
#  'советовать': 922,
#  'наталья': 923,
#  'изменить': 924,
#  'повторно': 925,
#  'абсолют': 926,
#  'качественный': 927,
#  'радовать': 928,
#  'приём': 929,
#  'глаз': 930,
#  'менять': 931,
#  '45': 932,
#  'вкладчик': 933,
#  'юридический': 934,
#  'девочка': 935,
#  'улица': 936,
#  'подход': 937,
#  'подтверждать': 938,
#  'метро': 939,
#  'скорее': 940,
#  '2-й': 941,
#  'сила': 942,
#  'подробный': 943,
#  'откуда': 944,
#  'ты': 945,
#  '--': 946,
#  'интересовать': 947,
#  'птс': 948,
#  'квитанция': 949,
#  'уходить': 950,
#  'ирина': 951,
#  'определённый': 952,
#  'доброжелательный': 953,
#  'покупать': 954,
#  'неоднократно': 955,
#  'семья': 956,
#  'совет': 957,
#  'таки': 958,
#  'многие': 959,
#  'хватать': 960,
#  'копейка': 961,
#  'зал': 962,
#  'call-центр': 963,
#  'автомобиль': 964,
#  'юлия': 965,
#  'назначить': 966,
#  'полчаса': 967,
#  'санкт-петербург': 968,
#  'ситибанк': 969,
#  'рублёвый': 970,
#  'хоум': 971,
#  'подарок': 972,
#  'татьяна': 973,
#  'низкий': 974,
#  'встречать': 975,
#  'заказывать': 976,
#  'доступный': 977,
#  '16': 978,
#  'продавец': 979,
#  'видно': 980,
#  'сталкиваться': 981,
#  'клиентский': 982,
#  'взыскание': 983,
#  'требоваться': 984,
#  'некий': 985,
#  'подключение': 986,
#  'статус': 987,
#  'оао': 988,
#  'рейтинг': 989,
#  'проект': 990,
#  'билет': 991,
#  'важный': 992,
#  'неприятный': 993,
#  'отменить': 994,
#  'перечислить': 995,
#  'надежда': 996,
#  'смысл': 997,
#  'пригласить': 998,
#  'увеличить': 999,
#  'поделиться': 1000,
#  'народ': 1001,
#  ...}

# %%
index_to_word
# Out:
# {2: 'банк',
#  3: 'карта',
#  4: 'это',
#  5: 'день',
#  6: 'мой',
#  7: 'сотрудник',
#  8: 'который',
#  9: 'кредит',
#  10: 'деньга',
#  11: 'счёт',
#  12: 'отделение',
#  13: 'клиент',
#  14: 'год',
#  15: 'сказать',
#  16: 'вопрос',
#  17: 'свой',
#  18: 'очень',
#  19: 'время',
#  20: 'сумма',
#  21: 'кредитный',
#  22: 'мочь',
#  23: 'получить',
#  24: 'офис',
#  25: 'такой',
#  26: 'проблема',
#  27: 'заявление',
#  28: 'договор',
#  29: 'работа',
#  30: 'платёж',
#  31: 'банкомат',
#  32: 'телефон',
#  33: 'позвонить',
#  34: 'месяц',
#  35: 'документ',
#  36: 'дать',
#  37: 'ответ',
#  38: 'решить',
#  39: 'хотеть',
#  40: 'обслуживание',
#  41: 'звонить',
#  42: 'ваш',
#  43: 'работать',
#  44: 'услуга',
#  45: 'претензия',
#  46: 'прийти',
#  47: 'вклад',
#  48: '«',
#  49: '»',
#  50: 'другой',
#  51: 'звонок',
#  52: 'номер',
#  53: 'написать',
#  54: 'один',
#  55: 'ситуация',
#  56: 'рубль',
#  57: 'человек',
#  58: 'минута',
#  59: 'сделать',
#  60: 'просто',
#  61: 'говорить',
#  62: 'средство',
#  63: 'быть',
#  64: 'альфа-банк',
#  65: 'заявка',
#  66: 'весь',
#  67: 'срок',
#  68: 'очередь',
#  69: '2',
#  70: 'первый',
#  71: 'знать',
#  72: 'информация',
#  73: 'новый',
#  74: 'оформить',
#  75: 'должный',
#  76: 'обратиться',
#  77: 'спасибо',
#  78: 'смс',
#  79: 'пользоваться',
#  80: 'девушка',
#  81: 'данный',
#  82: 'комиссия',
#  83: 'никакой',
#  84: 'несколько',
#  85: 'менеджер',
#  86: 'процент',
#  87: 'являться',
#  88: 'сайт',
#  89: 'операция',
#  90: 'какой',
#  91: 'я',
#  92: 'условие',
#  93: 'оператор',
#  94: 'отзыв',
#  95: 'стать',
#  96: 'сам',
#  97: 'решение',
#  98: 'нужно',
#  99: 'сообщить',
#  100: 'ждать',
#  101: 'сразу',
#  102: 'специалист',
#  103: 'также',
#  104: 'почему',
#  105: 'неделя',
#  106: 'перевод',
#  107: 'тот',
#  108: 'течение',
#  109: 'час',
#  110: 'сегодня',
#  111: 'ответить',
#  112: 'хотя',
#  113: 'т.к',
#  114: 'момент',
#  115: 'писать',
#  116: 'следующий',
#  117: 'обращение',
#  118: 'иметь',
#  119: '5',
#  120: 'открыть',
#  121: 'просить',
#  122: '3',
#  123: '–',
#  124: 'всё',
#  125: '10',
#  126: 'отношение',
#  127: 'г.',
#  128: 'взять',
#  129: 'быстро',
#  130: 'случай',
#  131: 'предложить',
#  132: 'хороший',
#  133: 'линия',
#  134: 'наш',
#  135: 'задолженность',
#  136: 'итог',
#  137: 'выдать',
#  138: 'самый',
#  139: 'вообще',
#  140: 'делать',
#  141: 'общий',
#  142: 'дело',
#  143: 'принять',
#  144: 'сбербанк',
#  145: 'лимит',
#  146: 'оказаться',
#  147: 'каждый',
#  148: 'этот',
#  149: 'смочь',
#  150: 'руб',
#  151: 'оплата',
#  152: 'нужный',
#  153: 'пройти',
#  154: 'пока',
#  155: 'приходить',
#  156: 'страховка',
#  157: 'объяснить',
#  158: 'думать',
#  159: 'слово',
#  160: 'какой-то',
#  161: 'получение',
#  162: 'помочь',
#  163: 'никто',
#  164: 'прийтись',
#  165: 'горячий',
#  166: 'погашение',
#  167: 'альфа',
#  168: 'оформление',
#  169: 'вернуть',
#  170: 'история',
#  171: 'брать',
#  172: 'попросить',
#  173: 'именно',
#  174: 'последний',
#  175: '1',
#  176: 'возможность',
#  177: 'сотрудница',
#  178: 'адрес',
#  179: 'закрыть',
#  180: 'получать',
#  181: 'узнать',
#  182: 'добрый',
#  183: 'служба',
#  184: 'интернет',
#  185: 'раз',
#  186: 'мы',
#  187: 'внести',
#  188: 'ошибка',
#  189: 'идти',
#  190: 'друг',
#  191: 'система',
#  192: 'хотеться',
#  193: 'указать',
#  194: 'оплатить',
#  195: 'снова',
#  196: 'любой',
#  197: 'рабочий',
#  198: 'москва',
#  199: 'денежный',
#  200: 'покупка',
#  201: 'около',
#  202: 'лицо',
#  203: 'платить',
#  204: 'положительный',
#  205: 'вежливый',
#  206: 'отправить',
#  207: 'снять',
#  208: 'оставить',
#  209: 'поэтому',
#  210: 'видеть',
#  211: 'назад',
#  212: 'касса',
#  213: 'связь',
#  214: 'конец',
#  215: 'поддержка',
#  216: 'дебетовый',
#  217: 'два',
#  218: '000',
#  219: 'остаться',
#  220: 'справка',
#  221: 'предоставить',
#  222: 'отвечать',
#  223: 'банковский',
#  224: 'второй',
#  225: 'погасить',
#  226: 'место',
#  227: 'карточка',
#  228: 'письмо',
#  229: 'обращаться',
#  230: 'полный',
#  231: 'ещё',
#  232: 'понимать',
#  233: 'просьба',
#  234: 'долг',
#  235: 'рассмотрение',
#  236: 'закрытие',
#  237: 'причина',
#  238: 'ставка',
#  239: 'открытие',
#  240: 'что-то',
#  241: 'приехать',
#  242: 'большой',
#  243: 'продукт',
#  244: 'дата',
#  245: 'находиться',
#  246: 'бинбанка',
#  247: 'страхование',
#  248: 'отказ',
#  249: 'приятно',
#  250: 'сторона',
#  251: 'давать',
#  252: 'личный',
#  253: 'уточнить',
#  254: 'результат',
#  255: 'действие',
#  256: 'выписка',
#  257: 'паспорт',
#  258: 'рассказать',
#  259: 'понять',
#  260: 'считать',
#  261: '4',
#  262: 'из-за',
#  263: 'авангард',
#  264: '30',
#  265: 'магазин',
#  266: 'отдел',
#  267: 'тариф',
#  268: 'оформлять',
#  269: 'кол-центр',
#  270: 'число',
#  271: 'сделка',
#  272: 'списать',
#  273: 'далее',
#  274: 'дополнительный',
#  275: 'отказаться',
#  276: 'найти',
#  277: 'спросить',
#  278: 'пара',
#  279: 'разобраться',
#  280: 'начать',
#  281: 'пытаться',
#  282: 'надеяться',
#  283: 'одобрить',
#  284: 'благодарность',
#  285: 'начало',
#  286: 'данные',
#  287: 'бинбанк',
#  288: 'удобный',
#  289: 'перезвонить',
#  290: 'обещать',
#  291: 'готовый',
#  292: 'город',
#  293: 'программа',
#  294: 'предложение',
#  295: 'пойти',
#  296: 'почта',
#  297: 'подать',
#  298: 'составить',
#  299: 'размер',
#  300: 'довольный',
#  301: 'внимание',
#  302: 'анкета',
#  303: 'сервис',
#  304: 'пора',
#  305: '15',
#  306: 'мобильный',
#  307: 'перевести',
#  308: 'произойти',
#  309: 'имя',
#  310: 'общение',
#  311: 'необходимый',
#  312: 'списание',
#  313: 'огромный',
#  314: 'помощь',
#  315: 'причём',
#  316: '20',
#  317: 'поступить',
#  318: 'возврат',
#  319: 'декабрь',
#  320: 'бесплатный',
#  321: 'отметить',
#  322: 'март',
#  323: 'снятие',
#  324: 'квартира',
#  325: 'долго',
#  326: 'её',
#  327: 'наличный',
#  328: 'стоить',
#  329: 'разный',
#  330: 'операционист',
#  331: 'заполнить',
#  332: 'интернет-банк',
#  333: 'некоторый',
#  334: 'качество',
#  335: 'маленький',
#  336: 'штраф',
#  337: 'рука',
#  338: 'очередной',
#  339: 'подписать',
#  340: 'период',
#  341: 'плюс',
#  342: 'компания',
#  343: 'остаток',
#  344: 'зарплатный',
#  345: 'филиал',
#  346: 'сколько',
#  347: 'провести',
#  348: 'больший',
#  349: 'ул',
#  350: 'забрать',
#  351: 'представитель',
#  352: 'зайти',
#  353: 'разговор',
#  354: 'просрочка',
#  355: 'сообщение',
#  356: 'депозит',
#  357: 'удобно',
#  358: 'действительно',
#  359: 'досрочный',
#  360: 'связаться',
#  361: 'близкий',
#  362: 'прислать',
#  363: 'обслуживаться',
#  364: 'сей',
#  365: 'уйти',
#  366: 'возникнуть',
#  367: 'подключить',
#  368: 'увидеть',
#  369: 'однако',
#  370: 'администратор',
#  371: 'т.е',
#  372: 'впечатление',
#  373: 'приятный',
#  374: 'кредитка',
#  375: 'порядок',
#  376: 'видимо',
#  377: 'пакет',
#  378: 'дом',
#  379: 'заблокировать',
#  380: 'право',
#  381: 'центр',
#  382: 'достаточно',
#  383: 'жалоба',
#  384: 'выбрать',
#  385: 'копия',
#  386: 'правда',
#  387: 'повод',
#  388: 'либо',
#  389: 'ожидание',
#  390: 'выдача',
#  391: 'страховой',
#  392: 'работник',
#  393: 'электронный',
#  394: 'сожаление',
#  395: 'необходимо',
#  396: 'положить',
#  397: 'организация',
#  398: 'давно',
#  399: 'предлагать',
#  400: 'оценка',
#  401: 'ранний',
#  402: 'высокий',
#  403: 'требовать',
#  404: 'факт',
#  405: 'терминал',
#  406: 'тысяча',
#  407: 'далёкий',
#  408: 'принимать',
#  409: 'лично',
#  410: 'запрос',
#  411: 'апрель',
#  412: 'проверить',
#  413: 'возможно',
#  414: '7',
#  415: 'начаться',
#  416: 'текущий',
#  417: 'подойти',
#  418: 'альф',
#  419: 'небольшой',
#  420: 'закрытый',
#  421: 'жизнь',
#  422: 'оплачивать',
#  423: 'вид',
#  424: 'полностью',
#  425: 'минус',
#  426: 'суд',
#  427: 'спрашивать',
#  428: 'точно',
#  429: 'кстати',
#  430: 'образ',
#  431: 'руководитель',
#  432: 'кроме',
#  433: 'курс',
#  434: 'май',
#  435: 'январь',
#  436: 'общаться',
#  437: 'посмотреть',
#  438: 'воспользоваться',
#  439: 'сначала',
#  440: 'отказать',
#  441: 'кто',
#  442: 'открывать',
#  443: 'быстрый',
#  444: 'единственный',
#  445: 'оперативно',
#  446: 'рассмотреть',
#  447: 'потребительский',
#  448: 'поставить',
#  449: 'руководство',
#  450: 'опыт',
#  451: 'всякий',
#  452: 'потратить',
#  453: 'требование',
#  454: 'ипотека',
#  455: 'часть',
#  456: 'объяснять',
#  457: 'снимать',
#  458: 'чек',
#  459: 'уровень',
#  460: 'ноябрь',
#  461: '6',
#  462: 'август',
#  463: 'годовой',
#  464: 'всё-таки',
#  465: '№',
#  466: 'сбер',
#  467: 'происходить',
#  468: 'сообщать',
#  469: 'февраль',
#  470: 'купюра',
#  471: 'технический',
#  472: 'процесс',
#  473: 'выразить',
#  474: 'понятно',
#  475: 'понравиться',
#  476: 'заказать',
#  477: 'заплатить',
#  478: 'отсутствие',
#  479: 'ранее',
#  480: 'простой',
#  481: 'рекомендовать',
#  482: 'туда',
#  483: 'приходиться',
#  484: 'вариант',
#  485: '8',
#  486: 'июль',
#  487: 'июнь',
#  488: 'фамилия',
#  489: 'подобный',
#  490: 'ежемесячный',
#  491: 'знакомый',
#  492: 'указанный',
#  493: 'занять',
#  494: 'забыть',
#  495: 'чётко',
#  496: 'бывать',
#  497: 'форма',
#  498: 'появиться',
#  499: 'возникать',
#  500: '100',
#  501: 'к',
#  502: 'уважаемый',
#  503: 'оказываться',
#  504: 'попытка',
#  505: 'валюта',
#  506: 'постоянно',
#  507: 'октябрь',
#  508: 'подождать',
#  509: 'решать',
#  510: 'примерно',
#  511: 'поздний',
#  512: 'вернуться',
#  513: 'акция',
#  514: 'третий',
#  515: 'дозвониться',
#  516: 'уважение',
#  517: 'попасть',
#  518: 'телефонный',
#  519: 'дальнейший',
#  520: 'начислить',
#  521: 'желание',
#  522: 'назвать',
#  523: 'вчера',
#  524: 'персонал',
#  525: 'здравствуйте',
#  526: 'утро',
#  527: 'например',
#  528: 'вносить',
#  529: 'лишь',
#  530: 'читать',
#  531: 'кабинет',
#  532: 'управлять',
#  533: 'вроде',
#  534: 'получиться',
#  535: 'спустя',
#  536: 'ожидать',
#  537: 'старый',
#  538: 'несмотря',
#  539: 'жена',
#  540: 'цель',
#  541: 'как-то',
#  542: 'смотреть',
#  543: 'рф',
#  544: 'естественно',
#  545: 'выясниться',
#  546: 'выдавать',
#  547: 'ипотечный',
#  548: 'сидеть',
#  549: 'сентябрь',
#  550: 'зачислить',
#  551: 'честно',
#  552: 'интернет-банка',
#  553: 'сетель',
#  554: 'поступать',
#  555: 'расчётный',
#  556: 'получаться',
#  557: 'подтвердить',
#  558: '2016',
#  559: 'выяснить',
#  560: 'поскольку',
#  561: 'ехать',
#  562: 'передать',
#  563: 'мало',
#  564: 'молодой',
#  565: 'трубка',
#  566: 'выйти',
#  567: 'перевыпуск',
#  568: 'главное',
#  569: 'россия',
#  570: 'выпустить',
#  571: 'плохой',
#  572: 'немного',
#  573: 'подумать',
#  574: 'менее',
#  575: 'помнить',
#  576: 'оставаться',
#  577: 'наверное',
#  578: 'проходить',
#  579: 'кассир',
#  580: 'ладный',
#  581: 'начинать',
#  582: 'заниматься',
#  583: 'отдельный',
#  584: 'кто-то',
#  585: 'равно',
#  586: 'вместо',
#  587: 'сотрудничество',
#  588: 'пожалуйста',
#  589: 'активировать',
#  590: 'нравиться',
#  591: 'процедура',
#  592: 'консультант',
#  593: 'ставить',
#  594: 'машина',
#  595: 'основание',
#  596: 'вечером',
#  597: 'кредитование',
#  598: 'бонус',
#  599: 'согласиться',
#  600: 'онлайн',
#  601: 'евро',
#  602: 'зарплата',
#  603: 'выбор',
#  604: 'отличный',
#  605: 'выпуск',
#  606: 'внесение',
#  607: 'сутки',
#  608: 'досрочно',
#  609: 'пункт',
#  610: 'потерять',
#  611: 'поехать',
#  612: 'необходимость',
#  613: 'обнаружить',
#  614: 'крупный',
#  615: 'реквизит',
#  616: 'закончиться',
#  617: 'доллар',
#  618: 'бумага',
#  619: 'целое',
#  620: 'посоветовать',
#  621: 'составлять',
#  622: 'особенно',
#  623: 'сбой',
#  624: 'обслуживать',
#  625: 'стоять',
#  626: 'собираться',
#  627: 'обычно',
#  628: 'visa',
#  629: 'подпись',
#  630: 'недавно',
#  631: 'московский',
#  632: 'персональный',
#  633: 'тыс',
#  634: 'уведомление',
#  635: '2014',
#  636: 'иметься',
#  637: 'практически',
#  638: 'консультация',
#  639: 'остальной',
#  640: 'пополнение',
#  641: 'минимальный',
#  642: 'завтра',
#  643: 'затем',
#  644: 'собственный',
#  645: 'количество',
#  646: 'бесплатно',
#  647: 'купить',
#  648: 'интересный',
#  649: 'база',
#  650: 'муж',
#  651: 'наличие',
#  652: 'ткс',
#  653: 'срочно',
#  654: 'правило',
#  655: 'использовать',
#  656: 'безопасность',
#  657: 'закон',
#  658: 'финансовый',
#  659: 'искать',
#  660: 'заранее',
#  661: 'изменение',
#  662: 'успеть',
#  663: 'отрицательный',
#  664: 'действовать',
#  665: 'часто',
#  666: 'льготный',
#  667: 'лишний',
#  668: 'процентный',
#  669: 'р.',
#  670: 'казаться',
#  671: 'подробно',
#  672: 'мера',
#  673: 'жить',
#  674: 'русский',
#  675: 'выходной',
#  676: 'заметить',
#  677: 'товар',
#  678: 'одобрение',
#  679: 'довольно',
#  680: 'пять',
#  681: 'невозможно',
#  682: 'удивить',
#  683: 'предыдущий',
#  684: 'т.д',
#  685: 'сложиться',
#  686: 'вечер',
#  687: 'подавать',
#  688: 'удаться',
#  689: 'профессионализм',
#  690: 'возможный',
#  691: 'стандарт',
#  692: '9',
#  693: 'вовремя',
#  694: 'отключить',
#  695: 'оставлять',
#  696: 'пример',
#  697: 'отдать',
#  698: 'предоставление',
#  699: 'пользование',
#  700: 'код',
#  701: 'нормальный',
#  702: 'выплата',
#  703: 'транзакция',
#  704: 'соответственно',
#  705: 'совершить',
#  706: 'выгодный',
#  707: 'подтверждение',
#  708: 'письменный',
#  709: '12',
#  710: 'совершенно',
#  711: 'план',
#  712: 'устраивать',
#  713: 'разбираться',
#  714: 'руб.',
#  715: 'проспект',
#  716: 'использование',
#  717: '2015',
#  718: 'мол',
#  719: 'крайне',
#  720: 'домой',
#  721: 'ввести',
#  722: 'стоимость',
#  723: 'доход',
#  724: 'зачисление',
#  725: 'подходить',
#  726: 'посещение',
#  727: 'закрывать',
#  728: 'какой-либо',
#  729: 'автокредит',
#  730: '50',
#  731: 'мнение',
#  732: 'удивление',
#  733: 'встреча',
#  734: 'благодаря',
#  735: 'желать',
#  736: 'продолжать',
#  737: 'выше',
#  738: 'тратить',
#  739: 'прошлый',
#  740: 'вы',
#  741: 'понедельник',
#  742: 'визит',
#  743: 'долгий',
#  744: 'перевыпустить',
#  745: 'админ',
#  746: 'проводить',
#  747: 'проверка',
#  748: 'заверить',
#  749: 'просрочить',
#  750: 'рядом',
#  751: 'платёжный',
#  752: 'график',
#  753: 'согласно',
#  754: 'тип',
#  755: 'пароль',
#  756: 'якобы',
#  757: 'никак',
#  758: 'случиться',
#  759: 'заявить',
#  760: '21',
#  761: 'операционистка',
#  762: 'согласие',
#  763: 'приложение',
#  764: 'услышать',
#  765: 'ребёнок',
#  766: 'наличные',
#  767: 'абсолютно',
#  768: 'зарегистрировать',
#  769: '40',
#  770: 'принцип',
#  771: 'задать',
#  772: 'предупредить',
#  773: 'направить',
#  774: 'начисление',
#  775: 'переводить',
#  776: 'обычный',
#  777: 'поблагодарить',
#  778: 'привести',
#  779: 'нормально',
#  780: 'попробовать',
#  781: 'вполне',
#  782: 'выполнить',
#  783: 'баланс',
#  784: 'подписывать',
#  785: '25',
#  786: 'полгода',
#  787: 'валютный',
#  788: 'держать',
#  789: 'настоящий',
#  790: 'ходить',
#  791: 'обязательно',
#  792: 'доступ',
#  793: '2013',
#  794: '11',
#  795: 'где-то',
#  796: 'состояние',
#  797: 'взнос',
#  798: 'внимательный',
#  799: 'вместе',
#  800: 'спокойно',
#  801: 'три',
#  802: 'коллега',
#  803: 'многий',
#  804: 'произвести',
#  805: 'вынудить',
#  806: 'регистрация',
#  807: 'буквально',
#  808: '14',
#  809: 'мкб',
#  810: 'подача',
#  811: 'предоставлять',
#  812: 'описать',
#  813: 'расчёт',
#  814: 'пояснить',
#  815: 'контактный',
#  816: 'слышать',
#  817: 'пополнить',
#  818: 'доп',
#  819: 'список',
#  820: 'точка',
#  821: 'себя',
#  822: 'исправить',
#  823: 'ооо',
#  824: 'понадобиться',
#  825: 'отказываться',
#  826: 'негативный',
#  827: 'прочитать',
#  828: 'обратно',
#  829: 'заходить',
#  830: 'отправлять',
#  831: 'конкретный',
#  832: 'решаться',
#  833: 'извинение',
#  834: 'обязательство',
#  835: 'мама',
#  836: 'они',
#  837: 'суббота',
#  838: '500',
#  839: 'елена',
#  840: 'постоянный',
#  841: 'мдм',
#  842: 'значит',
#  843: 'полис',
#  844: 'плата',
#  845: 'кодовый',
#  846: 'правильно',
#  847: 'иб',
#  848: '18',
#  849: 'куча',
#  850: 'помогать',
#  851: 'принести',
#  852: 'вход',
#  853: 'способ',
#  854: 'вывод',
#  855: 'рассрочка',
#  856: 'распечатать',
#  857: 'минимум',
#  858: 'оба',
#  859: 'нерв',
#  860: 'что',
#  861: 'подписание',
#  862: 'утром',
#  863: 'платный',
#  864: 'почему-то',
#  865: 'компьютер',
#  866: 'профессиональный',
#  867: 'мелочь',
#  868: 'ольга',
#  869: 'попытаться',
#  870: 'рассматривать',
#  871: 'приезжать',
#  872: 'разговаривать',
#  873: 'граница',
#  874: 'столкнуться',
#  875: 'прямо',
#  876: 'показать',
#  877: 'проверять',
#  878: 'мина',
#  879: 'окончание',
#  880: 'сильно',
#  881: 'узнавать',
#  882: 'уточнять',
#  883: 'официальный',
#  884: 'центральный',
#  885: 'оно',
#  886: 'относиться',
#  887: 'реклама',
#  888: 'вновь',
#  889: 'супруг',
#  890: 'грамотный',
#  891: 'послать',
#  892: 'компетентный',
#  893: 'обратить',
#  894: 'альфа-клик',
#  895: 'собственно',
#  896: 'пятница',
#  897: 'вина',
#  898: 'заполнять',
#  899: 'называть',
#  900: 'объяснение',
#  901: 'планировать',
#  902: 'удивлённый',
#  903: 'успешно',
#  904: 'александр',
#  905: 'понимание',
#  906: 'учёт',
#  907: 'страна',
#  908: 'пусть',
#  909: '24',
#  910: 'оперативность',
#  911: 'соответствовать',
#  912: 'екатерина',
#  913: 'оперативный',
#  914: 'отпуск',
#  915: 'поменять',
#  916: 'замечательный',
#  917: '—',
#  918: 'иной',
#  919: 'смена',
#  920: '3-й',
#  921: 'заёмщик',
#  922: 'советовать',
#  923: 'наталья',
#  924: 'изменить',
#  925: 'повторно',
#  926: 'абсолют',
#  927: 'качественный',
#  928: 'радовать',
#  929: 'приём',
#  930: 'глаз',
#  931: 'менять',
#  932: '45',
#  933: 'вкладчик',
#  934: 'юридический',
#  935: 'девочка',
#  936: 'улица',
#  937: 'подход',
#  938: 'подтверждать',
#  939: 'метро',
#  940: 'скорее',
#  941: '2-й',
#  942: 'сила',
#  943: 'подробный',
#  944: 'откуда',
#  945: 'ты',
#  946: '--',
#  947: 'интересовать',
#  948: 'птс',
#  949: 'квитанция',
#  950: 'уходить',
#  951: 'ирина',
#  952: 'определённый',
#  953: 'доброжелательный',
#  954: 'покупать',
#  955: 'неоднократно',
#  956: 'семья',
#  957: 'совет',
#  958: 'таки',
#  959: 'многие',
#  960: 'хватать',
#  961: 'копейка',
#  962: 'зал',
#  963: 'call-центр',
#  964: 'автомобиль',
#  965: 'юлия',
#  966: 'назначить',
#  967: 'полчаса',
#  968: 'санкт-петербург',
#  969: 'ситибанк',
#  970: 'рублёвый',
#  971: 'хоум',
#  972: 'подарок',
#  973: 'татьяна',
#  974: 'низкий',
#  975: 'встречать',
#  976: 'заказывать',
#  977: 'доступный',
#  978: '16',
#  979: 'продавец',
#  980: 'видно',
#  981: 'сталкиваться',
#  982: 'клиентский',
#  983: 'взыскание',
#  984: 'требоваться',
#  985: 'некий',
#  986: 'подключение',
#  987: 'статус',
#  988: 'оао',
#  989: 'рейтинг',
#  990: 'проект',
#  991: 'билет',
#  992: 'важный',
#  993: 'неприятный',
#  994: 'отменить',
#  995: 'перечислить',
#  996: 'надежда',
#  997: 'смысл',
#  998: 'пригласить',
#  999: 'увеличить',
#  1000: 'поделиться',
#  1001: 'народ',
#  ...}

# %%
# Функция, которая заменяет слово на соответсвующий ему индекс в word_to_index
def text_to_sequence(txt, word_to_index):
    seq = []
    for word in txt:
        index = word_to_index.get(word, 1) # 1 означает неизвестное слово
        # Неизвестные слова не добавляем в выходную последовательность
        if index != 1:
            seq.append(index)
    return seq

# %%
# Применяем функцию text_to_sequence к данным и сохраняем результаты в колонке Sequence
df_banks['Sequence'] = df_banks['Tokens'].apply(lambda row: text_to_sequence(row, word_to_index))

# %%
df_banks
# Out:
#        Score                                               Text  \
# idx
# 0          1  В Альфа-Банке работает замечательная девушка -...
# 1          0  Оформляя рассрочку в м. Видео в меге тёплый ст...
# 2          1  Очень порадовала оперативность работы в банке....
# 3          0  Имела неосторожность оформить потреб. кредит в...
# 4          0  Небольшая предыстория: Нашел на сайте MDM банк...
# ...      ...                                                ...
# 13994      1  О высокой надёжности МКБ, порядочности и добро...
# 13995      1  Обслуживаюсь в офисе на Чернореченской 42а, ка...
# 13996      1  Попала сегодня в очень неприятную ситуацию. Ре...
# 13997      1  Добрый день! Давно являюсь клиентом банка Русс...
# 13998      0  Сначала было все банально. Взял в кредит mp3 п...
#
#                                                   Tokens  \
# idx
# 0      [альфа-банк, работать, замечательный, девушка,...
# 1      [оформлять, рассрочка, м., видео, мег, тёплый,...
# 2      [очень, порадовать, оперативность, работа, бан...
# 3      [иметь, неосторожность, оформить, потреба, кре...
# 4      [небольшой, предыстория, найти, сайт, mdm, бан...
# ...                                                  ...
# 13994  [высокий, надёжность, мкб, порядочность, добро...
# 13995  [обслуживаться, офис, чернореченский, 42а, физ...
# 13996  [попасть, сегодня, очень, неприятный, ситуация...
# 13997  [добрый, день, давно, являться, клиент, банк, ...
# 13998  [сначала, банально, взять, кредит, mp3, плеер,...
#
#                                                 Sequence
# idx
# 0      [64, 43, 916, 80, 205, 1864, 358, 2704, 410, 1...
# 1      [268, 855, 1177, 3206, 3880, 2974, 7332, 172, ...
# 2      [18, 1055, 910, 29, 2, 476, 184, 3, 628, 1765,...
# 3      [118, 4805, 74, 2363, 9, 64, 18, 2658, 1286, 3...
# 4      [419, 3839, 276, 88, 2, 648, 3, 48, 4881, 123,...
# ...                                                  ...
# 13994  [402, 2316, 809, 5015, 8144, 7, 3090, 127, 442...
# 13995  [363, 24, 9481, 2147, 202, 14, 24, 96, 142, 68...
# 13996  [517, 110, 18, 993, 55, 38, 225, 234, 3, 46, 3...
# 13997  [182, 5, 398, 87, 13, 2, 674, 691, 118, 344, 3...
# 13998  [439, 4099, 128, 9, 461, 2033, 203, 660, 3972,...
#
# [13999 rows x 4 columns]

# %%
# Разбиваем данные на тренировочную и тестовую подвыборки
X_train, X_test, y_train, y_test = train_test_split(df_banks['Sequence'], df_banks['Score'],
                                                   random_state=42,
                                                   test_size=.2)

# %%
# Функия для векторизации 
def vectorize_sequences(sequences, dimension=10000):
    results = np.zeros((len(sequences), dimension))  # Создаем нулевую матрицу, где кол-во слов в словаре - стобцы, а длинна 
    # последовательности - строки
    for i, sequence in enumerate(sequences):
        for index in sequence:
            results[i, index] += 1.  # Если слово встреается в последовательности, 
            # то увеличиваем его векторное представление на 1
    return results

# %%
# Применяем вышеуказанную функцию к нашим фичам (признакам)
X_train = vectorize_sequences(X_train, 10000)
X_test = vectorize_sequences(X_test, 10000)

# %% [markdown]
# # Baseline

# %%
# Создаем 3 базовые модели
LogReg = LogisticRegression(max_iter=500)
rf = RandomForestClassifier()
cb = CatBoostClassifier(verbose=100, eval_metric='AUC')

# %%
# Обучаем модели
LogReg.fit(X_train, y_train)
rf.fit(X_train, y_train)
cb.fit(X_train, y_train)
# Out:
# Learning rate set to 0.028902
# 0:	total: 247ms	remaining: 4m 6s
# 100:	total: 6.71s	remaining: 59.7s
# 200:	total: 21s	remaining: 1m 23s
# 300:	total: 41.3s	remaining: 1m 35s
# 400:	total: 51.4s	remaining: 1m 16s
# 500:	total: 57.9s	remaining: 57.7s
# 600:	total: 1m 4s	remaining: 42.7s
# 700:	total: 1m 10s	remaining: 30.2s
# 800:	total: 1m 16s	remaining: 19.1s
# 900:	total: 1m 23s	remaining: 9.19s
# 999:	total: 1m 29s	remaining: 0us

# %%
# Функция, для сохранения метрик качества моделей в DataFrame
models = ['LogisticRegression', 'RandomForest', 'CatBoost']
y_pred = [LogReg.predict(X_test), rf.predict(X_test), cb.predict(X_test)]
df_metrics = pd.DataFrame()
for i in range(len(models)):
    s = pd.Series({'accuracy_score': accuracy_score(y_test, y_pred[i]),
                   'precision_score': precision_score(y_test, y_pred[i]), 
                   'recall_score': recall_score(y_test, y_pred[i]), 
                   'f1_score': f1_score(y_test, y_pred[i]),
                   'roc_auc_score': roc_auc_score(y_test, y_pred[i])},
                    name = models[i])
    df_metrics[models[i]] = s

# %%
df_metrics
# Out:
#                  LogisticRegression  RandomForest  CatBoost
# accuracy_score             0.940000      0.919643  0.927500
# precision_score            0.943764      0.942018  0.948949
# recall_score               0.935668      0.894210  0.903503
# f1_score                   0.939698      0.917492  0.925668
# roc_auc_score              0.939997      0.919625  0.927483
